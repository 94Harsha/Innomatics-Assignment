# %% [markdown]
# <a href="https://colab.research.google.com/github/94Harsha/Innomatics-Assignment/blob/main/Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Problem Statement 1: Employee Performance Bonus Eligibility

# %%
#Employee
employees = {
"Ravi": 92,
"Anita": 88,
"Kiran": 92,
"Suresh": 85
}
#High score
high_score = max(employees.values())
#multiple employee having the same high score
top_performers = [name for name, score in employees.items() if score == high_score]
#Display all employees eligible for the top performance bonus
print("Top performers Eligible for bonus:",",".join(top_performers),"(Score:",high_score, ")")
print()
# Out:
# Top performers Eligible for bonus: Ravi,Kiran (Score: 92 )

# %% [markdown]
# Problem Statement 2: Search Query Keyword Analysis

# %%
#query
query="Buy mobile phone buy phone online"
#Convert the input to lowercase
query=query.lower()
#Ignore common punctuation.
query=query.replace(".","")
query=query.replace(",","")
query=query.replace("?","")
query=query.replace("!","")
query=query.replace(":","")
query=query.replace(";","")
#split into words
words=query.split()
#Count the frequency of each keyword.
word_count={}
for word in words:
    if word in word_count:
        word_count[word]+=1
    else:
        word_count[word]=1
#Display only keywords searched more than once.
result={}
for word,count in word_count.items():
    if count>1:
        result[word]=count
print(result)
print()
# Out:
# {'buy': 2, 'phone': 2}

# %% [markdown]
# Problem Statement 3: Sensor Data Validation

# %%
sensor_readings = [3, 4, 7, 8, 10, 12, 5]
#Identify readings that are even numbers (valid readings).
valid_readings=[]
#Store them as (hour_index, reading_value) pairs.
for i,reading in enumerate(sensor_readings):
    if reading%2==0:
        valid_readings.append((i,reading))
#Ignore odd readings (invalid readings).
print("valid sensor readings (Hour,Value):")
print(valid_readings)
print()
# Out:
# valid sensor readings (Hour,Value):
# [(1, 4), (3, 8), (4, 10), (5, 12)]

# %% [markdown]
# Problem Statement 4: Email Domain Usage Analysis

# %%
emails = [
"ravi@gmail.com",
"anita@yahoo.com",
"kiran@gmail.com",
"suresh@gmail.com",
"meena@yahoo.com"
]
#Count how many users belong to each email domain.
domain_count={}
for email in emails:
    domain=email.split("@")[1]
    if domain in domain_count:
        domain_count[domain]+=1
    else:
        domain_count[domain]=1
total_emails=len(emails)
#Calculate the percentage usage of each domain.
for domain,count in domain_count.items():
    percentage=(count/total_emails)*100
    print(domain+":",str(int(percentage))+"%")
print()
# Out:
# gmail.com: 60%
# yahoo.com: 40%

# %% [markdown]
# Problem Statement 5: Sales Spike Detection

# %%
sales = [1200, 1500, 900, 2200, 1400, 3000]
#Calculate the average daily sales.
average=sum(sales)/len(sales)
#Detect days where sales are more than 30% above average.
threshold=1.3*average
for i in range(len(sales)):
    if sales[i]>threshold:
#Display the day number and sale value.
        print("Day",i+1,":",sales[i])
print()
# Out:
# Day 6 : 3000

# %% [markdown]
# Problem Statement 6: Duplicate User ID Detection

# %%
user_ids = ["user1", "user2", "user1", "user3", "user1", "user3"]
#Identify duplicate user IDs.
id_count={}
for id in user_ids:
    if id in id_count:
        id_count[id]+=1
    else:
        id_count[id]=1
#Display how many times each duplicate appears.
for id,count in id_count.items():
    if count>1:
        print(id,"->",count,"times")
# Out:
# user1 -> 3 times
# user3 -> 2 times
